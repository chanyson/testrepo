# %% [markdown]
# # Peer-graded assignment on Jupyter Notebook

# %% [markdown]
# In this notebook, Data science tools and ecosystem are summarized

# %% [markdown]
# ## List of data science languages
# 1. python
# 2. R
# 3. SQL
# 4. Julia
# 5. Scala
# 6. MATLAB
# 7. SAS

# %% [markdown]
# ## List of data science libraries
# - pandas
# - numpy
# - ggplot2
# - Matplotlib
# - Seaborn
# - Scikit-learn
# - Tensorflow
# - PyTorch
# - Dplyr
# - caret

# %% [markdown]
# ## table of data science tools
# | data science tools |
# |----------------|
# | MySQL |
# | mongoDB |
# | CouchDB |
# | Apache cassandra |
# | Apache Airflow |
# | IBM Watson Studio Desktop |
# | Tableau |
# | Prometheus |

# %% [markdown]
# ### jupyter notebook can clude arithmetic expressions like:
# (5*5)+4
# 200/60
# 4-5+7

# %%
(5*5)+4
# Out:
# 29

# %%
200 / 60
# Out:
# 3.3333333333333335

# %% [markdown]
# ## Objectives
# - List popular languages for data science
# - List poupular development environments
# - Create a jupyter notetook

# %% [markdown]
# ## Author ##
# Chanhee Son
